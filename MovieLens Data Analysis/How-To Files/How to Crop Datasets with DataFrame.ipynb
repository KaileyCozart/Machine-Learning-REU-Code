# %%
import pandas as pd

df = pd.read_csv('ratings.csv', header = 0, delimiter=',')
print (df)
# Out:
#           userId  movieId  rating   timestamp
# 0              1        2     3.5  1112486027
# 1              1       29     3.5  1112484676
# 2              1       32     3.5  1112484819
# 3              1       47     3.5  1112484727
# 4              1       50     3.5  1112484580
# 5              1      112     3.5  1094785740
# 6              1      151     4.0  1094785734
# 7              1      223     4.0  1112485573
# 8              1      253     4.0  1112484940
# 9              1      260     4.0  1112484826
# 10             1      293     4.0  1112484703
# 11             1      296     4.0  1112484767
# 12             1      318     4.0  1112484798
# 13             1      337     3.5  1094785709
# 14             1      367     3.5  1112485980
# 15             1      541     4.0  1112484603
# 16             1      589     3.5  1112485557
# 17             1      593     3.5  1112484661
# 18             1      653     3.0  1094785691
# ...

# %%
list(df)
# Out:
# ['userId', 'movieId', 'rating', 'timestamp']

# %%
df1 = df.drop(df.columns[[2, 3]], axis = 1).drop(df.index[101:20000263])
print (df1)
# Out:
#      userId  movieId
# 0         1        2
# 1         1       29
# 2         1       32
# 3         1       47
# 4         1       50
# 5         1      112
# 6         1      151
# 7         1      223
# 8         1      253
# 9         1      260
# 10        1      293
# 11        1      296
# 12        1      318
# 13        1      337
# 14        1      367
# 15        1      541
# 16        1      589
# 17        1      593
# 18        1      653
# 19        1      919
# 20        1      924
# 21        1     1009
# 22        1     1036
# 23        1     1079
# 24        1     1080
# 25        1     1089
# 26        1     1090
# 27        1     1097
# 28        1     1136
# 29        1     1193
# ..      ...      ...
# 71        1     2138
# 72        1     2140
# 73        1     2143
# 74        1     2173
# 75        1     2174
# 76        1     2193
# 77        1     2194
# 78        1     2253
# 79        1     2288
# 80        1     2291
# 81        1     2542
# ...
